# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import pandas as pd
import tensorflow as tf
import math
import tensorflow_addons as tfa
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from random import sample
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
from  tensorflow.keras.metrics import AUC, Precision, Recall, Accuracy
from tensorflow.keras.losses import BinaryCrossentropy, CategoricalCrossentropy

from utils import (
    plot_metrics,
    F1Score,
    plot_accuracy,
)
# Out:
# c:\Users\Paul\anaconda3\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.7.0 and strictly below 2.10.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# To Activate GPU if there is
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available:  1

# %%
data_directory = 'dataset'

train_img = pd.read_csv(os.path.join(data_directory, 'MURA-v1.1_mod/train_image_paths.csv'), names=['path'])

train_img
# Out:
#                                                     path
# 0      MURA-v1.1_mod/train/XR_SHOULDER/patient00001/s...
# 1      MURA-v1.1_mod/train/XR_SHOULDER/patient00001/s...
# 2      MURA-v1.1_mod/train/XR_SHOULDER/patient00001/s...
# 3      MURA-v1.1_mod/train/XR_SHOULDER/patient00002/s...
# 4      MURA-v1.1_mod/train/XR_SHOULDER/patient00002/s...
# ...                                                  ...
# 36803  MURA-v1.1_mod/train/XR_HAND/patient11183/study...
# 36804  MURA-v1.1_mod/train/XR_HAND/patient11183/study...
# 36805  MURA-v1.1_mod/train/XR_HAND/patient11184/study...
# 36806  MURA-v1.1_mod/train/XR_HAND/patient11184/study...
# 36807  MURA-v1.1_mod/train/XR_HAND/patient11184/study...
#
# [36808 rows x 1 columns]

# %%
orig_len = len(train_img)

# Split the train into training and validation dataset
valid_img= train_img.sample(frac=0.2, random_state=1337)

# Remove the selected image paths for the validation in training img paths
train_img = train_img.drop(valid_img.index)

valid_length = len(valid_img)
train_length = len(train_img)

print('Original Size of Train: ', orig_len)
print('Validation dataset size: ', valid_length)
print('Train dataset size: ', train_length)

assert(orig_len == (valid_length + train_length))
# Out:
# Original Size of Train:  36808
# Validation dataset size:  7362
# Train dataset size:  29446

# %%
# Add labels to the paths
train_img['label'] = train_img['path'].map(lambda x: '1' if 'positive' in x else '0')
valid_img['label'] = valid_img['path'].map(lambda x: '1' if 'positive' in x else '0')

train_class_frequency = pd.DataFrame(train_img['label'].value_counts())
valid_class_frequency = pd.DataFrame(valid_img['label'].value_counts())

print('Train Data Class Distribution: \n',train_class_frequency)
print('Validation Data Class Distribution: \n',valid_class_frequency)
# Out:
# Train Data Class Distribution:
#     label
# 0  17483
# 1  11963
# Validation Data Class Distribution:
#     label
# 0   4452
# 1   2910

# %%
img_height = img_width = 240

def apply_clahe(img):
    clahe = cv2.createCLAHE(clipLimit=4.0, tileGridSize=(8, 8))
    return clahe.apply(img.astype(np.uint8))

def resize_img(img):
    try:
        img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    except:
        print('error in resizing')
        img1 = isinstance(img, type(None))
        print('Does image is none: ', img1)
        print(img.shape)
    return cv2.resize(img, (img_height, img_width))

def canny_cropping(img):
    convert_img = np.array(img, dtype=np.uint8)

    gray = cv2.cvtColor(convert_img, cv2.COLOR_RGB2GRAY)


    ave_brightness = math.floor(np.average(gray))
    min_pixel = min(gray.flatten())

    edges = cv2.Canny(gray, min_pixel, ave_brightness)
    cnts = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    cnts = sorted(cnts, key=cv2.contourArea, reverse=True)

    for c in cnts:
        x, y, w, h = cv2.boundingRect(edges)
        gray = gray[y:y+h, x:x+w]
        break

    return gray


def preprocessing_with_clahe(img):
    cropped = canny_cropping(img)
    clahe = apply_clahe(cropped)
    return resize_img(clahe)

# %%
data_path = 'dataset/'
batch = 8
train_batches = ImageDataGenerator(
    rotation_range=30,
    horizontal_flip=True,
    preprocessing_function=preprocessing_with_clahe
).flow_from_dataframe(
    target_size=(img_height, img_width),
    dataframe=train_img, 
    directory= data_path,
    class_mode='binary',
    x_col='path',
    y_col='label',
    batch_size=batch)

valid_batches = ImageDataGenerator(
    preprocessing_function=preprocessing_with_clahe
).flow_from_dataframe(
    target_size=(img_height, img_width),
    dataframe= valid_img,
    directory= data_path,
    class_mode='binary',
    x_col='path',
    y_col='label',
    shuffle=False,
    batch_size=batch)
# Out:
# Found 29446 validated image filenames belonging to 2 classes.
# Found 7362 validated image filenames belonging to 2 classes.

# %%
METRICS = [ 
    tf.keras.metrics.BinaryAccuracy(),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
    F1Score(name="f1_score"),
]

reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_cohen_kappa",
    verbose=1,
    patience=4,
    mode="max",
    factor=0.1,
    min_lr=1e-5,
)

# %%
def build_model():

    # Create GlobalAveragePooling Layer
    global_ave_layer = tf.keras.layers.GlobalAveragePooling2D()

    prediction_layer = tf.keras.layers.Dense(1, activation='sigmoid')

    inputs = tf.keras.Input(shape=(img_height, img_width, 3))

    pretrained_model = tf.keras.applications.efficientnet_v2.EfficientNetV2B1(
        input_tensor = inputs,
        include_top=False,
        weights='imagenet',
        classes=2,
    )
    
    pretrained_model.trainable = False

    x = global_ave_layer(pretrained_model.output)
    x = tf.keras.layers.Dense(512, activation='swish')(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.9)(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(256, activation='swish')(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.9)(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = prediction_layer(x)
    model_with_clahe = Model(inputs, outputs)

    model_with_clahe.compile(
    optimizer=SGD(learning_rate=0.001, momentum=0.9), 
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=METRICS)

    return model_with_clahe

# %%
model_with_clahe = build_model()

# %%
with open('models/summary/feature_extraction_modified_with_CLAHE_summary.txt','w') as fh:
    model_with_clahe.summary(print_fn=lambda x: fh.write(x + '\n'))

# %%
print(np.sum([tf.keras.backend.count_params(w) for w in model_with_clahe.trainable_weights]))
print(np.sum([tf.keras.backend.count_params(w) for w in model_with_clahe.non_trainable_weights]))
# Out:
# 788993
# 6932660

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_cohen_kappa",
    verbose=1,
    patience=5,
    mode="max",
    baseline=0.0,
    restore_best_weights=True,
)

base_model_name = 'efficientnetv2-b1'
model_path = f'models/with_clahe/{base_model_name}_modified_feature_extractor_v2.h5'
checkpoint_feature = tf.keras.callbacks.ModelCheckpoint(
    filepath=model_path,
    monitor='val_cohen_kappa',
    mode='max',
    save_best_only = True,
)

feature_training = f'training_records/with_clahe/{base_model_name}_modified_feature_extraction_v2.csv'
logs = tf.keras.callbacks.CSVLogger(filename=feature_training, separator=',')

# %%
if os.path.isfile(model_path) is False:
    history = model_with_clahe.fit(
        train_batches, 
        validation_data=valid_batches, 
        epochs=25, 
        verbose=2,
        callbacks=[early_stopping, checkpoint_feature, logs, reduce_lr_on_plateau],
    )
# Out:
# Epoch 1/25
# 3681/3681 - 608s - loss: 0.6538 - binary_accuracy: 0.6444 - precision: 0.5714 - recall: 0.4994 - cohen_kappa: 0.2480 - f1_score: 0.5330 - val_loss: 0.5782 - val_binary_accuracy: 0.6952 - val_precision: 0.6031 - val_recall: 0.6694 - val_cohen_kappa: 0.3743 - val_f1_score: 0.6345 - lr: 0.0010 - 608s/epoch - 165ms/step
# Epoch 2/25
# 3681/3681 - 594s - loss: 0.6137 - binary_accuracy: 0.6780 - precision: 0.6239 - recall: 0.5221 - cohen_kappa: 0.3148 - f1_score: 0.5685 - val_loss: 0.5675 - val_binary_accuracy: 0.7274 - val_precision: 0.6978 - val_recall: 0.5474 - val_cohen_kappa: 0.4076 - val_f1_score: 0.6135 - lr: 0.0010 - 594s/epoch - 161ms/step
# Epoch 3/25
# 3681/3681 - 638s - loss: 0.6062 - binary_accuracy: 0.6811 - precision: 0.6306 - recall: 0.5191 - cohen_kappa: 0.3200 - f1_score: 0.5695 - val_loss: 0.5496 - val_binary_accuracy: 0.7293 - val_precision: 0.6761 - val_recall: 0.6048 - val_cohen_kappa: 0.4232 - val_f1_score: 0.6385 - lr: 0.0010 - 638s/epoch - 173ms/step
# Epoch 4/25
# 3681/3681 - 592s - loss: 0.5993 - binary_accuracy: 0.6875 - precision: 0.6380 - recall: 0.5332 - cohen_kappa: 0.3349 - f1_score: 0.5809 - val_loss: 0.5275 - val_binary_accuracy: 0.7453 - val_precision: 0.7397 - val_recall: 0.5488 - val_cohen_kappa: 0.4423 - val_f1_score: 0.6301 - lr: 0.0010 - 592s/epoch - 161ms/step
# Epoch 5/25
# 3681/3681 - 585s - loss: 0.5938 - binary_accuracy: 0.6936 - precision: 0.6476 - recall: 0.5392 - cohen_kappa: 0.3476 - f1_score: 0.5885 - val_loss: 0.5373 - val_binary_accuracy: 0.7459 - val_precision: 0.7436 - val_recall: 0.5450 - val_cohen_kappa: 0.4426 - val_f1_score: 0.6290 - lr: 0.0010 - 585s/epoch - 159ms/step
# Epoch 6/25
# 3681/3681 - 581s - loss: 0.5890 - binary_accuracy: 0.6988 - precision: 0.6564 - recall: 0.5427 - cohen_kappa: 0.3580 - f1_score: 0.5941 - val_loss: 0.5354 - val_binary_accuracy: 0.7471 - val_precision: 0.6944 - val_recall: 0.6433 - val_cohen_kappa: 0.4641 - val_f1_score: 0.6679 - lr: 0.0010 - 581s/epoch - 158ms/step
# Epoch 7/25
# 3681/3681 - 580s - loss: 0.5869 - binary_accuracy: 0.6996 - precision: 0.6549 - recall: 0.5508 - cohen_kappa: 0.3613 - f1_score: 0.5983 - val_loss: 0.5294 - val_binary_accuracy: 0.7480 - val_precision: 0.7367 - val_recall: 0.5643 - val_cohen_kappa: 0.4507 - val_f1_score: 0.6390 - lr: 0.0010 - 580s/epoch - 158ms/step
# Epoch 8/25
# 3681/3681 - 585s - loss: 0.5858 - binary_accuracy: 0.6991 - precision: 0.6540 - recall: 0.5510 - cohen_kappa: 0.3605 - f1_score: 0.5981 - val_loss: 0.5226 - val_binary_accuracy: 0.7469 - val_precision: 0.7110 - val_recall: 0.6062 - val_cohen_kappa: 0.4568 - val_f1_score: 0.6544 - lr: 0.0010 - 585s/epoch - 159ms/step
# Epoch 9/25
# 3681/3681 - 581s - loss: 0.5804 - binary_accuracy: 0.7046 - precision: 0.6649 - recall: 0.5504 - cohen_kappa: 0.3707 - f1_score: 0.6022 - val_loss: 0.5230 - val_binary_accuracy: 0.7456 - val_precision: 0.6923 - val_recall: 0.6416 - val_cohen_kappa: 0.4610 - val_f1_score: 0.6660 - lr: 0.0010 - 581s/epoch - 158ms/step
# Epoch 10/25
# 3681/3681 - 574s - loss: 0.5757 - binary_accuracy: 0.7065 - precision: 0.6664 - recall: 0.5561 - cohen_kappa: 0.3754 - f1_score: 0.6063 - val_loss: 0.5198 - val_binary_accuracy: 0.7522 - val_precision: 0.7136 - val_recall: 0.6234 - val_cohen_kappa: 0.4701 - val_f1_score: 0.6654 - lr: 0.0010 - 574s/epoch - 156ms/step
# Epoch 11/25
# 3681/3681 - 595s - loss: 0.5799 - binary_accuracy: 0.7036 - precision: 0.6607 - recall: 0.5560 - cohen_kappa: 0.3698 - f1_score: 0.6038 - val_loss: 0.5137 - val_binary_accuracy: 0.7567 - val_precision: 0.7303 - val_recall: 0.6096 - val_cohen_kappa: 0.4761 - val_f1_score: 0.6645 - lr: 0.0010 - 595s/epoch - 162ms/step
# Epoch 12/25
# 3681/3681 - 583s - loss: 0.5763 - binary_accuracy: 0.7075 - precision: 0.6688 - recall: 0.5550 - cohen_kappa: 0.3770 - f1_score: 0.6066 - val_loss: 0.5475 - val_binary_accuracy: 0.7244 - val_precision: 0.6338 - val_recall: 0.7172 - val_cohen_kappa: 0.4363 - val_f1_score: 0.6729 - lr: 0.0010 - 583s/epoch - 158ms/step
# Epoch 13/25
# 3681/3681 - 571s - loss: 0.5754 - binary_accuracy: 0.7095 - precision: 0.6706 - recall: 0.5603 - cohen_kappa: 0.3819 - f1_score: 0.6105 - val_loss: 0.5202 - val_binary_accuracy: 0.7529 - val_precision: 0.7550 - val_recall: 0.5550 - val_cohen_kappa: 0.4583 - val_f1_score: 0.6397 - lr: 0.0010 - 571s/epoch - 155ms/step
# Epoch 14/25
# 3681/3681 - 571s - loss: 0.5684 - binary_accuracy: 0.7147 - precision: 0.6776 - recall: 0.5679 - cohen_kappa: 0.3930 - f1_score: 0.6179 - val_loss: 0.5153 - val_binary_accuracy: 0.7582 - val_precision: 0.7406 - val_recall: 0.5976 - val_cohen_kappa: 0.4767 - val_f1_score: 0.6615 - lr: 0.0010 - 571s/epoch - 155ms/step
# Epoch 15/25
# 3681/3681 - 582s - loss: 0.5707 - binary_accuracy: 0.7135 - precision: 0.6766 - recall: 0.5646 - cohen_kappa: 0.3901 - f1_score: 0.6155 - val_loss: 0.5161 - val_binary_accuracy: 0.7577 - val_precision: 0.7525 - val_recall: 0.5766 - val_cohen_kappa: 0.4717 - val_f1_score: 0.6529 - lr: 0.0010 - 582s/epoch - 158ms/step
# Epoch 16/25
# 3681/3681 - 577s - loss: 0.5688 - binary_accuracy: 0.7142 - precision: 0.6764 - recall: 0.5686 - cohen_kappa: 0.3923 - f1_score: 0.6178 - val_loss: 0.5094 - val_binary_accuracy: 0.7607 - val_precision: 0.7291 - val_recall: 0.6278 - val_cohen_kappa: 0.4870 - val_f1_score: 0.6747 - lr: 0.0010 - 577s/epoch - 157ms/step
# Epoch 17/25
# 3681/3681 - 582s - loss: 0.5672 - binary_accuracy: 0.7158 - precision: 0.6783 - recall: 0.5712 - cohen_kappa: 0.3957 - f1_score: 0.6202 - val_loss: 0.5055 - val_binary_accuracy: 0.7639 - val_precision: 0.7550 - val_recall: 0.5962 - val_cohen_kappa: 0.4875 - val_f1_score: 0.6663 - lr: 0.0010 - 582s/epoch - 158ms/step
# Epoch 18/25
# 3681/3681 - 598s - loss: 0.5680 - binary_accuracy: 0.7143 - precision: 0.6785 - recall: 0.5641 - cohen_kappa: 0.3916 - f1_score: 0.6160 - val_loss: 0.5108 - val_binary_accuracy: 0.7597 - val_precision: 0.7349 - val_recall: 0.6134 - val_cohen_kappa: 0.4826 - val_f1_score: 0.6687 - lr: 0.0010 - 598s/epoch - 162ms/step
# Epoch 19/25
# 3681/3681 - 578s - loss: 0.5642 - binary_accuracy: 0.7187 - precision: 0.6852 - recall: 0.5690 - cohen_kappa: 0.4008 - f1_score: 0.6217 - val_loss: 0.5131 - val_binary_accuracy: 0.7566 - val_precision: 0.6945 - val_recall: 0.6859 - val_cohen_kappa: 0.4897 - val_f1_score: 0.6902 - lr: 0.0010 - 578s/epoch - 157ms/step
# Epoch 20/25
# 3681/3681 - 574s - loss: 0.5616 - binary_accuracy: 0.7200 - precision: 0.6852 - recall: 0.5751 - cohen_kappa: 0.4046 - f1_score: 0.6253 - val_loss: 0.5123 - val_binary_accuracy: 0.7571 - val_precision: 0.7822 - val_recall: 0.5344 - val_cohen_kappa: 0.4625 - val_f1_score: 0.6350 - lr: 0.0010 - 574s/epoch - 156ms/step
# Epoch 21/25
# 3681/3681 - 574s - loss: 0.5577 - binary_accuracy: 0.7198 - precision: 0.6843 - recall: 0.5759 - cohen_kappa: 0.4042 - f1_score: 0.6255 - val_loss: 0.5104 - val_binary_accuracy: 0.7570 - val_precision: 0.6987 - val_recall: 0.6773 - val_cohen_kappa: 0.4890 - val_f1_score: 0.6878 - lr: 0.0010 - 574s/epoch - 156ms/step
# Epoch 22/25
# 3681/3681 - 572s - loss: 0.5602 - binary_accuracy: 0.7202 - precision: 0.6859 - recall: 0.5745 - cohen_kappa: 0.4048 - f1_score: 0.6253 - val_loss: 0.5193 - val_binary_accuracy: 0.7589 - val_precision: 0.7377 - val_recall: 0.6052 - val_cohen_kappa: 0.4795 - val_f1_score: 0.6649 - lr: 0.0010 - 572s/epoch - 155ms/step
# Epoch 23/25
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 3681/3681 - 573s - loss: 0.5581 - binary_accuracy: 0.7232 - precision: 0.6895 - recall: 0.5796 - cohen_kappa: 0.4113 - f1_score: 0.6298 - val_loss: 0.5310 - val_binary_accuracy: 0.7411 - val_precision: 0.6689 - val_recall: 0.6832 - val_cohen_kappa: 0.4604 - val_f1_score: 0.6760 - lr: 0.0010 - 573s/epoch - 156ms/step
# Epoch 24/25
# 3681/3681 - 571s - loss: 0.5420 - binary_accuracy: 0.7324 - precision: 0.7130 - recall: 0.5710 - cohen_kappa: 0.4272 - f1_score: 0.6342 - val_loss: 0.5017 - val_binary_accuracy: 0.7676 - val_precision: 0.7512 - val_recall: 0.6162 - val_cohen_kappa: 0.4982 - val_f1_score: 0.6770 - lr: 1.0000e-04 - 571s/epoch - 155ms/step
# Epoch 25/25
# 3681/3681 - 573s - loss: 0.5383 - binary_accuracy: 0.7369 - precision: 0.7179 - recall: 0.5805 - cohen_kappa: 0.4377 - f1_score: 0.6419 - val_loss: 0.5056 - val_binary_accuracy: 0.7650 - val_precision: 0.7826 - val_recall: 0.5615 - val_cohen_kappa: 0.4832 - val_f1_score: 0.6539 - lr: 1.0000e-04 - 573s/epoch - 156ms/step

# %%
if os.path.isfile(model_path) is False:
    print('Model Saved')
    model_with_clahe.save(model_path)

# %%
plot_metrics(history)

# %%
plot_accuracy(history)

# %%
## Finetuning
trained_model = tf.keras.models.load_model(
    model_path,
    custom_objects={'F1Score': F1Score}
)

# %%
def unfreeze_model(model):
    for layer in model.layers[:]:
        if not isinstance(layer, tf.keras.layers.BatchNormalization):
            layer.trainable = True
    model.compile(
        optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, clipnorm=1.0),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS
    )

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_cohen_kappa",
    verbose=1,
    patience=4,
    mode="max",
    factor=0.2,
    min_lr=1e-10,
)

base_model_name = 'efficientnetv2-b1'
finetune_path = f'models/with_clahe/{base_model_name}_modified_finetuned_v2.h5'

finetuning_checkpoint  = tf.keras.callbacks.ModelCheckpoint(
    filepath=finetune_path,
    monitor='val_cohen_kappa',
    mode='max',
    save_best_only = True,
)

finetuning = f'training_records/with_clahe/{base_model_name}_modified_finetuning_v2.csv'
fine_logs = tf.keras.callbacks.CSVLogger(filename=finetuning, separator=',')

# %%
unfreeze_model(trained_model)

# %%
print(np.sum([tf.keras.backend.count_params(w) for w in trained_model.trainable_weights]))
print(np.sum([tf.keras.backend.count_params(w) for w in trained_model.non_trainable_weights]))
# Out:
# 7577973
# 143680

# %%
finetune_history = trained_model.fit(
    train_batches,
    epochs=25, 
    validation_data=valid_batches,
    callbacks=[early_stopping, reduce_lr_on_plateau, finetuning_checkpoint, fine_logs],
)
# Out:
# Epoch 1/25
# 3681/3681 [==============================] - 831s 220ms/step - loss: 0.5573 - binary_accuracy: 0.7322 - precision: 0.7103 - recall: 0.5698 - cohen_kappa: 0.4257 - f1_score: 0.6323 - val_loss: 0.4925 - val_binary_accuracy: 0.7787 - val_precision: 0.8483 - val_recall: 0.5361 - val_cohen_kappa: 0.5056 - val_f1_score: 0.6570 - lr: 0.0010
# Epoch 2/25
# 3681/3681 [==============================] - 807s 219ms/step - loss: 0.5294 - binary_accuracy: 0.7518 - precision: 0.7312 - recall: 0.6151 - cohen_kappa: 0.4723 - f1_score: 0.6682 - val_loss: 0.4871 - val_binary_accuracy: 0.7789 - val_precision: 0.7885 - val_recall: 0.6021 - val_cohen_kappa: 0.5177 - val_f1_score: 0.6828 - lr: 0.0010
# Epoch 3/25
# 3681/3681 [==============================] - 807s 219ms/step - loss: 0.5167 - binary_accuracy: 0.7654 - precision: 0.7485 - recall: 0.6363 - cohen_kappa: 0.5019 - f1_score: 0.6879 - val_loss: 0.4625 - val_binary_accuracy: 0.8020 - val_precision: 0.8377 - val_recall: 0.6189 - val_cohen_kappa: 0.5661 - val_f1_score: 0.7119 - lr: 0.0010
# Epoch 4/25
# 3681/3681 [==============================] - 806s 219ms/step - loss: 0.5029 - binary_accuracy: 0.7744 - precision: 0.7622 - recall: 0.6463 - cohen_kappa: 0.5209 - f1_score: 0.6995 - val_loss: 0.4736 - val_binary_accuracy: 0.8022 - val_precision: 0.8432 - val_recall: 0.6137 - val_cohen_kappa: 0.5658 - val_f1_score: 0.7104 - lr: 0.0010
# Epoch 5/25
# 3681/3681 [==============================] - 812s 221ms/step - loss: 0.5001 - binary_accuracy: 0.7745 - precision: 0.7584 - recall: 0.6531 - cohen_kappa: 0.5222 - f1_score: 0.7018 - val_loss: 0.4530 - val_binary_accuracy: 0.8015 - val_precision: 0.8536 - val_recall: 0.6010 - val_cohen_kappa: 0.5625 - val_f1_score: 0.7054 - lr: 0.0010
# Epoch 6/25
# 3681/3681 [==============================] - 818s 222ms/step - loss: 0.4950 - binary_accuracy: 0.7794 - precision: 0.7671 - recall: 0.6563 - cohen_kappa: 0.5321 - f1_score: 0.7074 - val_loss: 0.4587 - val_binary_accuracy: 0.7957 - val_precision: 0.7613 - val_recall: 0.7038 - val_cohen_kappa: 0.5670 - val_f1_score: 0.7314 - lr: 0.0010
# Epoch 7/25
# 3681/3681 [==============================] - 810s 220ms/step - loss: 0.4899 - binary_accuracy: 0.7816 - precision: 0.7661 - recall: 0.6656 - cohen_kappa: 0.5377 - f1_score: 0.7123 - val_loss: 0.4431 - val_binary_accuracy: 0.8101 - val_precision: 0.7731 - val_recall: 0.7354 - val_cohen_kappa: 0.5994 - val_f1_score: 0.7538 - lr: 0.0010
# Epoch 8/25
# 3681/3681 [==============================] - 810s 220ms/step - loss: 0.4776 - binary_accuracy: 0.7919 - precision: 0.7790 - recall: 0.6810 - cohen_kappa: 0.5600 - f1_score: 0.7267 - val_loss: 0.4663 - val_binary_accuracy: 0.8051 - val_precision: 0.8156 - val_recall: 0.6550 - val_cohen_kappa: 0.5779 - val_f1_score: 0.7265 - lr: 0.0010
# Epoch 9/25
# 3681/3681 [==============================] - 824s 224ms/step - loss: 0.4791 - binary_accuracy: 0.7912 - precision: 0.7792 - recall: 0.6783 - cohen_kappa: 0.5582 - f1_score: 0.7252 - val_loss: 0.4433 - val_binary_accuracy: 0.8086 - val_precision: 0.7848 - val_recall: 0.7107 - val_cohen_kappa: 0.5930 - val_f1_score: 0.7459 - lr: 0.0010
# Epoch 10/25
# 3681/3681 [==============================] - 853s 232ms/step - loss: 0.4714 - binary_accuracy: 0.7935 - precision: 0.7799 - recall: 0.6849 - cohen_kappa: 0.5635 - f1_score: 0.7293 - val_loss: 0.4416 - val_binary_accuracy: 0.8109 - val_precision: 0.8070 - val_recall: 0.6856 - val_cohen_kappa: 0.5939 - val_f1_score: 0.7414 - lr: 0.0010
# Epoch 11/25
# 3681/3681 [==============================] - 847s 230ms/step - loss: 0.4682 - binary_accuracy: 0.7978 - precision: 0.7867 - recall: 0.6892 - cohen_kappa: 0.5726 - f1_score: 0.7348 - val_loss: 0.4456 - val_binary_accuracy: 0.8189 - val_precision: 0.8544 - val_recall: 0.6533 - val_cohen_kappa: 0.6052 - val_f1_score: 0.7404 - lr: 0.0010
# Epoch 12/25
# 3681/3681 [==============================] - 819s 222ms/step - loss: 0.4589 - binary_accuracy: 0.8041 - precision: 0.7890 - recall: 0.7068 - cohen_kappa: 0.5871 - f1_score: 0.7456 - val_loss: 0.4257 - val_binary_accuracy: 0.8236 - val_precision: 0.8513 - val_recall: 0.6708 - val_cohen_kappa: 0.6168 - val_f1_score: 0.7503 - lr: 0.0010
# Epoch 13/25
# 3681/3681 [==============================] - 818s 222ms/step - loss: 0.4603 - binary_accuracy: 0.8044 - precision: 0.7924 - recall: 0.7025 - cohen_kappa: 0.5871 - f1_score: 0.7447 - val_loss: 0.4436 - val_binary_accuracy: 0.8102 - val_precision: 0.7994 - val_recall: 0.6942 - val_cohen_kappa: 0.5938 - val_f1_score: 0.7431 - lr: 0.0010
# Epoch 14/25
# 3681/3681 [==============================] - 815s 221ms/step - loss: 0.4513 - binary_accuracy: 0.8088 - precision: 0.7998 - recall: 0.7061 - cohen_kappa: 0.5962 - f1_score: 0.7500 - val_loss: 0.4485 - val_binary_accuracy: 0.8113 - val_precision: 0.8108 - val_recall: 0.6818 - val_cohen_kappa: 0.5942 - val_f1_score: 0.7407 - lr: 0.0010
# Epoch 15/25
# 3681/3681 [==============================] - 841s 228ms/step - loss: 0.4444 - binary_accuracy: 0.8121 - precision: 0.7996 - recall: 0.7172 - cohen_kappa: 0.6041 - f1_score: 0.7562 - val_loss: 0.4398 - val_binary_accuracy: 0.8120 - val_precision: 0.7644 - val_recall: 0.7581 - val_cohen_kappa: 0.6062 - val_f1_score: 0.7612 - lr: 0.0010
# Epoch 16/25
# 3681/3681 [==============================] - ETA: 0s - loss: 0.4476 - binary_accuracy: 0.8123 - precision: 0.8038 - recall: 0.7119 - cohen_kappa: 0.6038 - f1_score: 0.7550
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 3681/3681 [==============================] - 829s 225ms/step - loss: 0.4476 - binary_accuracy: 0.8123 - precision: 0.8038 - recall: 0.7119 - cohen_kappa: 0.6038 - f1_score: 0.7550 - val_loss: 0.4304 - val_binary_accuracy: 0.8184 - val_precision: 0.8112 - val_recall: 0.7045 - val_cohen_kappa: 0.6113 - val_f1_score: 0.7541 - lr: 0.0010
# Epoch 17/25
# 3681/3681 [==============================] - 834s 226ms/step - loss: 0.4141 - binary_accuracy: 0.8297 - precision: 0.8192 - recall: 0.7452 - cohen_kappa: 0.6419 - f1_score: 0.7805 - val_loss: 0.4231 - val_binary_accuracy: 0.8259 - val_precision: 0.8093 - val_recall: 0.7320 - val_cohen_kappa: 0.6296 - val_f1_score: 0.7687 - lr: 2.0000e-04
# Epoch 18/25
# 3681/3681 [==============================] - 822s 223ms/step - loss: 0.4064 - binary_accuracy: 0.8352 - precision: 0.8284 - recall: 0.7496 - cohen_kappa: 0.6532 - f1_score: 0.7870 - val_loss: 0.4322 - val_binary_accuracy: 0.8259 - val_precision: 0.8187 - val_recall: 0.7186 - val_cohen_kappa: 0.6279 - val_f1_score: 0.7654 - lr: 2.0000e-04
# Epoch 19/25
# 3681/3681 [==============================] - 818s 222ms/step - loss: 0.4084 - binary_accuracy: 0.8365 - precision: 0.8321 - recall: 0.7486 - cohen_kappa: 0.6556 - f1_score: 0.7881 - val_loss: 0.4343 - val_binary_accuracy: 0.8264 - val_precision: 0.8215 - val_recall: 0.7165 - val_cohen_kappa: 0.6287 - val_f1_score: 0.7654 - lr: 2.0000e-04
# Epoch 20/25
# 3681/3681 [==============================] - 814s 221ms/step - loss: 0.3991 - binary_accuracy: 0.8388 - precision: 0.8328 - recall: 0.7547 - cohen_kappa: 0.6608 - f1_score: 0.7918 - val_loss: 0.4306 - val_binary_accuracy: 0.8231 - val_precision: 0.8092 - val_recall: 0.7230 - val_cohen_kappa: 0.6231 - val_f1_score: 0.7637 - lr: 2.0000e-04
# Epoch 21/25
# 3681/3681 [==============================] - ETA: 0s - loss: 0.3984 - binary_accuracy: 0.8429 - precision: 0.8357 - recall: 0.7634 - cohen_kappa: 0.6698 - f1_score: 0.7979
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 3681/3681 [==============================] - 807s 219ms/step - loss: 0.3984 - binary_accuracy: 0.8429 - precision: 0.8357 - recall: 0.7634 - cohen_kappa: 0.6698 - f1_score: 0.7979 - val_loss: 0.4246 - val_binary_accuracy: 0.8259 - val_precision: 0.8358 - val_recall: 0.6962 - val_cohen_kappa: 0.6249 - val_f1_score: 0.7597 - lr: 2.0000e-04
# Epoch 22/25
# 3681/3681 [==============================] - 807s 219ms/step - loss: 0.3946 - binary_accuracy: 0.8423 - precision: 0.8396 - recall: 0.7562 - cohen_kappa: 0.6679 - f1_score: 0.7958 - val_loss: 0.4257 - val_binary_accuracy: 0.8256 - val_precision: 0.8059 - val_recall: 0.7361 - val_cohen_kappa: 0.6296 - val_f1_score: 0.7694 - lr: 4.0000e-05
# Epoch 23/25
# 3681/3681 [==============================] - 807s 219ms/step - loss: 0.3851 - binary_accuracy: 0.8453 - precision: 0.8391 - recall: 0.7661 - cohen_kappa: 0.6748 - f1_score: 0.8009 - val_loss: 0.4373 - val_binary_accuracy: 0.8236 - val_precision: 0.8085 - val_recall: 0.7254 - val_cohen_kappa: 0.6242 - val_f1_score: 0.7647 - lr: 4.0000e-05
# Epoch 24/25
# 3681/3681 [==============================] - 808s 219ms/step - loss: 0.3851 - binary_accuracy: 0.8474 - precision: 0.8430 - recall: 0.7673 - cohen_kappa: 0.6792 - f1_score: 0.8034 - val_loss: 0.4331 - val_binary_accuracy: 0.8253 - val_precision: 0.8085 - val_recall: 0.7313 - val_cohen_kappa: 0.6285 - val_f1_score: 0.7680 - lr: 4.0000e-05
# Epoch 25/25
# 3681/3681 [==============================] - ETA: 0s - loss: 0.3845 - binary_accuracy: 0.8480 - precision: 0.8450 - recall: 0.7664 - cohen_kappa: 0.6801 - f1_score: 0.8038
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 3681/3681 [==============================] - 806s 219ms/step - loss: 0.3845 - binary_accuracy: 0.8480 - precision: 0.8450 - recall: 0.7664 - cohen_kappa: 0.6801 - f1_score: 0.8038 - val_loss: 0.4403 - val_binary_accuracy: 0.8245 - val_precision: 0.8102 - val_recall: 0.7261 - val_cohen_kappa: 0.6262 - val_f1_score: 0.7659 - lr: 4.0000e-05

# %%
plot_metrics(finetune_history)

# %%
plot_accuracy(finetune_history)

# %%
# get the loss value & metrics values for the model in validation mode
evaluation_metrics = trained_model.evaluate(valid_batches, verbose=1)
# Out:
# 921/921 [==============================] - 56s 61ms/step - loss: 0.4403 - binary_accuracy: 0.8245 - precision: 0.8102 - recall: 0.7261 - cohen_kappa: 0.6262 - f1_score: 0.7659

# %%
loss = evaluation_metrics.pop(0)

print(f"val loss    : {loss}")
for metric, score in zip(METRICS, evaluation_metrics):

    print(f"{metric.name + ' ' * (12 - len(metric.name))}: {score}")
# Out:
# val loss    : 0.44030115008354187
# binary_accuracy: 0.8245041966438293
# precision   : 0.8101993799209595
# recall      : 0.7261168360710144
# cohen_kappa : 0.6261850595474243
# f1_score    : 0.7658572196960449

# %%
if os.path.isfile(finetune_path) is False:
    trained_model.save(finetune_path)
