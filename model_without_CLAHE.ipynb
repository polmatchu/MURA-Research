# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import pandas as pd
import tensorflow as tf
import math
import tensorflow_addons as tfa
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from random import sample
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from  tensorflow.keras.metrics import AUC, Precision, Recall, Accuracy
from tensorflow.keras.losses import BinaryCrossentropy, CategoricalCrossentropy
from utils import plot_metrics
from utils import F1Score
from utils import plot_accuracy

# %%
# To Activate GPU if there is
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available:  1
# 2022-09-19 04:13:00.578659: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-19 04:13:00.615814: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-19 04:13:00.616126: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
data_directory = 'dataset'

train_img = pd.read_csv(os.path.join(data_directory, 'MURA-v1.1/train_image_paths.csv'), names=['path'])
test_img = pd.read_csv(os.path.join(data_directory, 'MURA-v1.1/test_image_paths.csv'), names=['path'])

train_img
# Out:
#                                                     path
# 0      MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 1      MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 2      MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 3      MURA-v1.1/train/XR_SHOULDER/patient00002/study...
# 4      MURA-v1.1/train/XR_SHOULDER/patient00002/study...
# ...                                                  ...
# 36803  MURA-v1.1/train/XR_HAND/patient11183/study1_ne...
# 36804  MURA-v1.1/train/XR_HAND/patient11183/study1_ne...
# 36805  MURA-v1.1/train/XR_HAND/patient11184/study1_ne...
# 36806  MURA-v1.1/train/XR_HAND/patient11184/study1_ne...
# 36807  MURA-v1.1/train/XR_HAND/patient11184/study1_ne...
#
# [36808 rows x 1 columns]

# %%
orig_len = len(train_img)

# Split the train into training and validation dataset
valid_img= train_img.sample(frac=0.2, random_state=1337)

# Remove the selected image paths for the validation in training img paths
train_img = train_img.drop(valid_img.index)

valid_length = len(valid_img)
train_length = len(train_img)

print('Original Size of Train: ', orig_len)
print('Validation dataset size: ', valid_length)
print('Train dataset size: ', train_length)

assert(orig_len == (valid_length + train_length))
# Out:
# Original Size of Train:  36808
# Validation dataset size:  7362
# Train dataset size:  29446

# %%
train_img
# Out:
#                                                     path
# 0      MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 1      MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 2      MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 3      MURA-v1.1/train/XR_SHOULDER/patient00002/study...
# 4      MURA-v1.1/train/XR_SHOULDER/patient00002/study...
# ...                                                  ...
# 36802  MURA-v1.1/train/XR_HAND/patient11183/study1_ne...
# 36804  MURA-v1.1/train/XR_HAND/patient11183/study1_ne...
# 36805  MURA-v1.1/train/XR_HAND/patient11184/study1_ne...
# 36806  MURA-v1.1/train/XR_HAND/patient11184/study1_ne...
# 36807  MURA-v1.1/train/XR_HAND/patient11184/study1_ne...
#
# [29446 rows x 1 columns]

# %%
# Add labels to the paths
train_img['label'] = train_img['path'].map(lambda x: '1' if 'positive' in x else '0')
valid_img['label'] = valid_img['path'].map(lambda x: '1' if 'positive' in x else '0')
test_img['label'] = test_img['path'].map(lambda x: '1' if 'positive' in x else '0')

train_class_frequency = pd.DataFrame(train_img['label'].value_counts())
valid_class_frequency = pd.DataFrame(valid_img['label'].value_counts())
test_class_frequency = pd.DataFrame(test_img['label'].value_counts())

print('Train Data Class Distribution: \n',train_class_frequency)
print('Validation Data Class Distribution: \n',valid_class_frequency)
print('Test Data Class Disribution: \n', test_class_frequency)
# Out:
# Train Data Class Distribution:
#     label
# 0  17483
# 1  11963
# Validation Data Class Distribution:
#     label
# 0   4452
# 1   2910
# Test Data Class Disribution:
#     label
# 0   1667
# 1   1530

# %% [markdown]
# # Image Preprocesing

# %%
img_height = img_width = 300

def resize_img(img):
    try:
        img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    except:
        print('error in resizing')
        img1 = isinstance(img, type(None))
        print('Does image is none: ', img1)
        print(img.shape)
    return cv2.resize(img, (img_height, img_width))

def canny_cropping(img):
    convert_img = np.array(img, dtype=np.uint8)

    gray = cv2.cvtColor(convert_img, cv2.COLOR_RGB2GRAY)


    ave_brightness = math.floor(np.average(gray))
    min_pixel = min(gray.flatten())

    edges = cv2.Canny(gray, min_pixel, ave_brightness)
    cnts = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    cnts = sorted(cnts, key=cv2.contourArea, reverse=True)

    for c in cnts:
        x, y, w, h = cv2.boundingRect(edges)
        gray = gray[y:y+h, x:x+w]
        break

    return gray

def preprocessing_without_clahe(img):
    cropped = canny_cropping(img)
    return resize_img(cropped)

# %%
data_path = 'dataset/'
batch = 8
train_batches = ImageDataGenerator(
    rotation_range=30,
    horizontal_flip=True,
    preprocessing_function=preprocessing_without_clahe
).flow_from_dataframe(
    target_size=(img_height, img_width),
    dataframe=train_img, 
    directory= data_path,
    class_mode='binary',
    x_col='path',
    y_col='label',
    batch_size=batch)

valid_batches = ImageDataGenerator(
    preprocessing_function=preprocessing_without_clahe
).flow_from_dataframe(
    target_size=(img_height, img_width),
    dataframe= valid_img,
    directory= data_path,
    class_mode='binary',
    x_col='path',
    y_col='label',
    shuffle=False,
    batch_size=batch)

test_batches = ImageDataGenerator(
    preprocessing_function=preprocessing_without_clahe
).flow_from_dataframe(
    target_size=(img_height, img_width),
    dataframe=test_img, 
    directory= data_path,
    class_mode='binary',
    x_col='path',
    y_col='label',
    batch_size=batch, 
    shuffle=False)
# Out:
# Found 29446 validated image filenames belonging to 2 classes.
# Found 7362 validated image filenames belonging to 2 classes.
# Found 3197 validated image filenames belonging to 2 classes.

# %% [markdown]
# # Model Construction
# ## Feature Extraction

# %%
# Load the pretrained base model of EfficientNetV2
feature_extractor = tf.keras.applications.efficientnet_v2.EfficientNetV2B3(
    include_top=False,
    weights='imagenet',
    classes=2,
)
# Out:
# 2022-09-19 04:14:35.764484: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-19 04:14:35.767165: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-19 04:14:35.767712: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-19 04:14:35.768177: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-19 04:14:37.231951: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-19 04:14:37.232611: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-19 04:14:37.232643: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2022-09-19 04:14:37.233136: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-19 04:14:37.233250: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5440 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Freeze the convulutional base
feature_extractor.trainable = False

# %%
# feature_extractor.summary()

# %%
METRICS = [ 
    tf.keras.metrics.BinaryAccuracy(),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
    F1Score(name="f1_score"),
]

# %%
def build_model():
    
    image_batch, label_batch = next(iter(train_batches))
    feature_batch = feature_extractor(image_batch)

    # Create GlobalAveragePooling Layer
    global_ave_layer = tf.keras.layers.GlobalAveragePooling2D()
    feature_batch_ave = global_ave_layer(feature_batch)

    prediction_layer = tf.keras.layers.Dense(1, activation='sigmoid')
    prediction_batch = prediction_layer(feature_batch_ave)

    inputs = tf.keras.Input(shape=(img_height, img_width, 3))
    x = feature_extractor(inputs, training=False)
    x = global_ave_layer(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    outputs = prediction_layer(x)
    model_without_clahe = Model(inputs, outputs)

    model_without_clahe.compile(
    optimizer=Adam(learning_rate=0.0001), 
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=METRICS)

    return model_without_clahe

# %%
model_without_clahe = build_model()
# Out:
# 2022-09-18 20:49:15.731690: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 2022-09-18 20:49:16.290730: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-18 20:49:16.458296: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.

# %%
model_without_clahe.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  efficientnetv2-b3 (Function  (None, None, None, 1536)  12930622
#  al)
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 1536)             6144
#  ormalization)
#
#  dropout (Dropout)           (None, 1536)              0
#
#  dense (Dense)               (None, 1)                 1537
#
# =================================================================
# Total params: 12,938,303
# Trainable params: 4,609
# Non-trainable params: 12,933,694
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model_without_clahe,
    to_file=f"images/efficientNet_without_clahe_diagram.png",
    show_shapes=True,
    show_layer_names=True,
)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_cohen_kappa",
    verbose=1,
    patience=5,
    mode="max",
    baseline=0.0,
    restore_best_weights=True,
)

base_model_name = feature_extractor.name
model_path = f'models/without_clahe/{base_model_name}_feature_extractor.h5'
checkpoint_feature = tf.keras.callbacks.ModelCheckpoint(
    filepath=model_path,
    monitor='val_cohen_kappa',
    mode='max',
    save_best_only = True,
)

feature_training = f'training_records/without_clahe/{base_model_name}_feature_extraction.csv'
logs = tf.keras.callbacks.CSVLogger(filename=feature_training, separator=',')

# %%
if os.path.isfile(model_path) is False:
    history = model_without_clahe.fit(
        train_batches, 
        validation_data=valid_batches, 
        epochs=25, 
        verbose=2,
        callbacks=[early_stopping, checkpoint_feature, logs],
    )
# Out:
# Epoch 1/25
# 3681/3681 - 578s - loss: 0.6840 - binary_accuracy: 0.6313 - precision: 0.5529 - recall: 0.4840 - cohen_kappa: 0.2205 - f1_score: 0.5161 - val_loss: 0.5912 - val_binary_accuracy: 0.7092 - val_precision: 0.6578 - val_recall: 0.5509 - val_cohen_kappa: 0.3741 - val_f1_score: 0.5996 - 578s/epoch - 157ms/step
# Epoch 2/25
# 3681/3681 - 562s - loss: 0.6094 - binary_accuracy: 0.6828 - precision: 0.6307 - recall: 0.5291 - cohen_kappa: 0.3254 - f1_score: 0.5755 - val_loss: 0.5569 - val_binary_accuracy: 0.7263 - val_precision: 0.6833 - val_recall: 0.5732 - val_cohen_kappa: 0.4110 - val_f1_score: 0.6234 - 562s/epoch - 153ms/step
# Epoch 3/25
# 3681/3681 - 566s - loss: 0.5892 - binary_accuracy: 0.6976 - precision: 0.6533 - recall: 0.5447 - cohen_kappa: 0.3562 - f1_score: 0.5941 - val_loss: 0.5485 - val_binary_accuracy: 0.7306 - val_precision: 0.6830 - val_recall: 0.5945 - val_cohen_kappa: 0.4236 - val_f1_score: 0.6357 - 566s/epoch - 154ms/step
# Epoch 4/25
# 3681/3681 - 584s - loss: 0.5757 - binary_accuracy: 0.7090 - precision: 0.6726 - recall: 0.5525 - cohen_kappa: 0.3792 - f1_score: 0.6067 - val_loss: 0.5370 - val_binary_accuracy: 0.7438 - val_precision: 0.7088 - val_recall: 0.5973 - val_cohen_kappa: 0.4491 - val_f1_score: 0.6483 - 584s/epoch - 159ms/step
# Epoch 5/25
# 3681/3681 - 586s - loss: 0.5693 - binary_accuracy: 0.7131 - precision: 0.6788 - recall: 0.5576 - cohen_kappa: 0.3881 - f1_score: 0.6123 - val_loss: 0.5371 - val_binary_accuracy: 0.7393 - val_precision: 0.6841 - val_recall: 0.6326 - val_cohen_kappa: 0.4476 - val_f1_score: 0.6574 - 586s/epoch - 159ms/step
# Epoch 6/25
# 3681/3681 - 575s - loss: 0.5639 - binary_accuracy: 0.7173 - precision: 0.6843 - recall: 0.5647 - cohen_kappa: 0.3974 - f1_score: 0.6188 - val_loss: 0.5413 - val_binary_accuracy: 0.7373 - val_precision: 0.6663 - val_recall: 0.6718 - val_cohen_kappa: 0.4513 - val_f1_score: 0.6691 - 575s/epoch - 156ms/step
# Epoch 7/25
# 3681/3681 - 577s - loss: 0.5653 - binary_accuracy: 0.7149 - precision: 0.6819 - recall: 0.5592 - cohen_kappa: 0.3918 - f1_score: 0.6145 - val_loss: 0.5293 - val_binary_accuracy: 0.7482 - val_precision: 0.7286 - val_recall: 0.5784 - val_cohen_kappa: 0.4537 - val_f1_score: 0.6448 - 577s/epoch - 157ms/step
# Epoch 8/25
# 3681/3681 - 589s - loss: 0.5554 - binary_accuracy: 0.7189 - precision: 0.6885 - recall: 0.5625 - cohen_kappa: 0.3999 - f1_score: 0.6192 - val_loss: 0.5293 - val_binary_accuracy: 0.7449 - val_precision: 0.6897 - val_recall: 0.6447 - val_cohen_kappa: 0.4603 - val_f1_score: 0.6664 - 589s/epoch - 160ms/step
# Epoch 9/25
# 3681/3681 - 560s - loss: 0.5560 - binary_accuracy: 0.7215 - precision: 0.6919 - recall: 0.5668 - cohen_kappa: 0.4057 - f1_score: 0.6232 - val_loss: 0.5357 - val_binary_accuracy: 0.7414 - val_precision: 0.6727 - val_recall: 0.6732 - val_cohen_kappa: 0.4591 - val_f1_score: 0.6730 - 560s/epoch - 152ms/step
# Epoch 10/25
# 3681/3681 - 544s - loss: 0.5565 - binary_accuracy: 0.7196 - precision: 0.6906 - recall: 0.5611 - cohen_kappa: 0.4009 - f1_score: 0.6191 - val_loss: 0.5289 - val_binary_accuracy: 0.7493 - val_precision: 0.7264 - val_recall: 0.5866 - val_cohen_kappa: 0.4574 - val_f1_score: 0.6490 - 544s/epoch - 148ms/step
# Epoch 11/25
# 3681/3681 - 544s - loss: 0.5552 - binary_accuracy: 0.7220 - precision: 0.6932 - recall: 0.5662 - cohen_kappa: 0.4065 - f1_score: 0.6233 - val_loss: 0.5260 - val_binary_accuracy: 0.7494 - val_precision: 0.7146 - val_recall: 0.6093 - val_cohen_kappa: 0.4620 - val_f1_score: 0.6578 - 544s/epoch - 148ms/step
# Epoch 12/25
# 3681/3681 - 531s - loss: 0.5537 - binary_accuracy: 0.7238 - precision: 0.6975 - recall: 0.5652 - cohen_kappa: 0.4097 - f1_score: 0.6244 - val_loss: 0.5252 - val_binary_accuracy: 0.7498 - val_precision: 0.7035 - val_recall: 0.6344 - val_cohen_kappa: 0.4676 - val_f1_score: 0.6671 - 531s/epoch - 144ms/step
# Epoch 13/25
# 3681/3681 - 569s - loss: 0.5545 - binary_accuracy: 0.7226 - precision: 0.6935 - recall: 0.5683 - cohen_kappa: 0.4081 - f1_score: 0.6247 - val_loss: 0.5252 - val_binary_accuracy: 0.7495 - val_precision: 0.7272 - val_recall: 0.5863 - val_cohen_kappa: 0.4579 - val_f1_score: 0.6492 - 569s/epoch - 155ms/step
# Epoch 14/25
# 3681/3681 - 569s - loss: 0.5519 - binary_accuracy: 0.7263 - precision: 0.7008 - recall: 0.5697 - cohen_kappa: 0.4155 - f1_score: 0.6285 - val_loss: 0.5259 - val_binary_accuracy: 0.7486 - val_precision: 0.6978 - val_recall: 0.6419 - val_cohen_kappa: 0.4667 - val_f1_score: 0.6687 - 569s/epoch - 155ms/step
# Epoch 15/25
# 3681/3681 - 576s - loss: 0.5532 - binary_accuracy: 0.7238 - precision: 0.6969 - recall: 0.5665 - cohen_kappa: 0.4100 - f1_score: 0.6250 - val_loss: 0.5211 - val_binary_accuracy: 0.7536 - val_precision: 0.7368 - val_recall: 0.5859 - val_cohen_kappa: 0.4656 - val_f1_score: 0.6528 - 576s/epoch - 156ms/step
# Epoch 16/25
# 3681/3681 - 574s - loss: 0.5511 - binary_accuracy: 0.7246 - precision: 0.6989 - recall: 0.5661 - cohen_kappa: 0.4115 - f1_score: 0.6255 - val_loss: 0.5264 - val_binary_accuracy: 0.7484 - val_precision: 0.7156 - val_recall: 0.6034 - val_cohen_kappa: 0.4591 - val_f1_score: 0.6547 - 574s/epoch - 156ms/step
# Epoch 17/25
# 3681/3681 - 577s - loss: 0.5518 - binary_accuracy: 0.7263 - precision: 0.7008 - recall: 0.5695 - cohen_kappa: 0.4154 - f1_score: 0.6284 - val_loss: 0.5281 - val_binary_accuracy: 0.7503 - val_precision: 0.7044 - val_recall: 0.6347 - val_cohen_kappa: 0.4687 - val_f1_score: 0.6678 - 577s/epoch - 157ms/step
# Epoch 18/25
# 3681/3681 - 540s - loss: 0.5514 - binary_accuracy: 0.7255 - precision: 0.7011 - recall: 0.5654 - cohen_kappa: 0.4131 - f1_score: 0.6260 - val_loss: 0.5223 - val_binary_accuracy: 0.7541 - val_precision: 0.7245 - val_recall: 0.6100 - val_cohen_kappa: 0.4712 - val_f1_score: 0.6623 - 540s/epoch - 147ms/step
# Epoch 19/25
# 3681/3681 - 545s - loss: 0.5532 - binary_accuracy: 0.7205 - precision: 0.6915 - recall: 0.5632 - cohen_kappa: 0.4031 - f1_score: 0.6208 - val_loss: 0.5250 - val_binary_accuracy: 0.7482 - val_precision: 0.7162 - val_recall: 0.6010 - val_cohen_kappa: 0.4581 - val_f1_score: 0.6536 - 545s/epoch - 148ms/step
# Epoch 20/25
# 3681/3681 - 553s - loss: 0.5509 - binary_accuracy: 0.7239 - precision: 0.6963 - recall: 0.5681 - cohen_kappa: 0.4105 - f1_score: 0.6257 - val_loss: 0.5249 - val_binary_accuracy: 0.7559 - val_precision: 0.7357 - val_recall: 0.5969 - val_cohen_kappa: 0.4722 - val_f1_score: 0.6591 - 553s/epoch - 150ms/step
# Epoch 21/25
# 3681/3681 - 553s - loss: 0.5535 - binary_accuracy: 0.7248 - precision: 0.6976 - recall: 0.5693 - cohen_kappa: 0.4125 - f1_score: 0.6270 - val_loss: 0.5226 - val_binary_accuracy: 0.7506 - val_precision: 0.7194 - val_recall: 0.6052 - val_cohen_kappa: 0.4636 - val_f1_score: 0.6573 - 553s/epoch - 150ms/step
# Epoch 22/25
# 3681/3681 - 547s - loss: 0.5513 - binary_accuracy: 0.7248 - precision: 0.6999 - recall: 0.5647 - cohen_kappa: 0.4115 - f1_score: 0.6250 - val_loss: 0.5266 - val_binary_accuracy: 0.7475 - val_precision: 0.7057 - val_recall: 0.6196 - val_cohen_kappa: 0.4604 - val_f1_score: 0.6598 - 547s/epoch - 149ms/step
# Epoch 23/25
# 3681/3681 - 556s - loss: 0.5539 - binary_accuracy: 0.7245 - precision: 0.6984 - recall: 0.5664 - cohen_kappa: 0.4113 - f1_score: 0.6255 - val_loss: 0.5206 - val_binary_accuracy: 0.7547 - val_precision: 0.7335 - val_recall: 0.5959 - val_cohen_kappa: 0.4696 - val_f1_score: 0.6576 - 556s/epoch - 151ms/step
# Epoch 24/25
# 3681/3681 - 566s - loss: 0.5508 - binary_accuracy: 0.7252 - precision: 0.6978 - recall: 0.5708 - cohen_kappa: 0.4135 - f1_score: 0.6279 - val_loss: 0.5244 - val_binary_accuracy: 0.7474 - val_precision: 0.7217 - val_recall: 0.5873 - val_cohen_kappa: 0.4539 - val_f1_score: 0.6476 - 566s/epoch - 154ms/step
# Epoch 25/25
# Restoring model weights from the end of the best epoch: 20.
# 3681/3681 - 555s - loss: 0.5551 - binary_accuracy: 0.7224 - precision: 0.6961 - recall: 0.5621 - cohen_kappa: 0.4066 - f1_score: 0.6220 - val_loss: 0.5250 - val_binary_accuracy: 0.7501 - val_precision: 0.7252 - val_recall: 0.5921 - val_cohen_kappa: 0.4600 - val_f1_score: 0.6519 - 555s/epoch - 151ms/step
# Epoch 25: early stopping

# %%
if os.path.isfile(model_path) is False:
    print('Model Saved')
    model_without_clahe.save(model_path)

# %%
plot_metrics(history)

# %%
plot_accuracy(history)

# %% [markdown]
# ## Finetuning

# %%
## Finetuning
trained_model = tf.keras.models.load_model(
    model_path,
    custom_objects={'F1Score': F1Score}
)

# %%
print("number of layers in the base model: ", len(feature_extractor.layers))
# Out:
# number of layers in the base model:  409

# %%
trained_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  efficientnetv2-b3 (Function  (None, None, None, 1536)  12930622
#  al)
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 1536)             6144
#  ormalization)
#
#  dropout (Dropout)           (None, 1536)              0
#
#  dense (Dense)               (None, 1)                 1537
#
# =================================================================
# Total params: 12,938,303
# Trainable params: 4,609
# Non-trainable params: 12,933,694
# _________________________________________________________________

# %%
def unfreeze_model(model):
    base_model = model.layers[1]
    base_model.trainable = True
    # print(len(base_model.layers))
    # for layer in base_model.layers[:-20]:
    #     layer.trainable = True
    
    model.compile(
        optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS
    )

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_cohen_kappa",
    verbose=1,
    patience=4,
    mode="max",
    factor=0.2,
    min_lr=1e-10,
)

base_model_name = feature_extractor.name
finetune_path = f'models/without_clahe/{base_model_name}_finetuned.h5'

finetuning_checkpoint  = tf.keras.callbacks.ModelCheckpoint(
    filepath=finetune_path,
    monitor='val_cohen_kappa',
    mode='max',
    save_best_only = True,
)

finetuning = f'training_records/without_clahe/{base_model_name}_finetuning.csv'
fine_logs = tf.keras.callbacks.CSVLogger(filename=finetuning, separator=',')

# %%
unfreeze_model(trained_model)

# %%
trained_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  efficientnetv2-b3 (Function  (None, None, None, 1536)  12930622
#  al)
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 1536)             6144
#  ormalization)
#
#  dropout (Dropout)           (None, 1536)              0
#
#  dense (Dense)               (None, 1)                 1537
#
# =================================================================
# Total params: 12,938,303
# Trainable params: 12,826,015
# Non-trainable params: 112,288
# _________________________________________________________________

# %%
finetune_history = trained_model.fit(
    train_batches,
    epochs=25, 
    validation_data=valid_batches,
    callbacks=[early_stopping, reduce_lr_on_plateau, finetuning_checkpoint, fine_logs],
)
# Out:
# Epoch 1/25
# 3681/3681 [==============================] - 655s 174ms/step - loss: 0.5236 - binary_accuracy: 0.7503 - precision: 0.7275 - recall: 0.6107 - cohen_kappa: 0.4677 - f1_score: 0.6640 - val_loss: 0.4512 - val_binary_accuracy: 0.8005 - val_precision: 0.8078 - val_recall: 0.6498 - val_cohen_kappa: 0.5680 - val_f1_score: 0.7202 - lr: 1.0000e-05
# Epoch 2/25
# 3681/3681 [==============================] - 627s 170ms/step - loss: 0.4759 - binary_accuracy: 0.7834 - precision: 0.7680 - recall: 0.6690 - cohen_kappa: 0.5417 - f1_score: 0.7151 - val_loss: 0.4460 - val_binary_accuracy: 0.8075 - val_precision: 0.8159 - val_recall: 0.6625 - val_cohen_kappa: 0.5838 - val_f1_score: 0.7313 - lr: 1.0000e-05
# Epoch 3/25
# 3681/3681 [==============================] - 617s 168ms/step - loss: 0.4519 - binary_accuracy: 0.7999 - precision: 0.7875 - recall: 0.6951 - cohen_kappa: 0.5774 - f1_score: 0.7384 - val_loss: 0.4271 - val_binary_accuracy: 0.8158 - val_precision: 0.7876 - val_recall: 0.7313 - val_cohen_kappa: 0.6099 - val_f1_score: 0.7584 - lr: 1.0000e-05
# Epoch 4/25
# 3681/3681 [==============================] - 614s 167ms/step - loss: 0.4264 - binary_accuracy: 0.8156 - precision: 0.8022 - recall: 0.7250 - cohen_kappa: 0.6119 - f1_score: 0.7616 - val_loss: 0.4241 - val_binary_accuracy: 0.8172 - val_precision: 0.8208 - val_recall: 0.6876 - val_cohen_kappa: 0.6065 - val_f1_score: 0.7483 - lr: 1.0000e-05
# Epoch 5/25
# 3681/3681 [==============================] - 681s 185ms/step - loss: 0.4052 - binary_accuracy: 0.8258 - precision: 0.8163 - recall: 0.7370 - cohen_kappa: 0.6333 - f1_score: 0.7746 - val_loss: 0.4846 - val_binary_accuracy: 0.7810 - val_precision: 0.7062 - val_recall: 0.7639 - val_cohen_kappa: 0.5484 - val_f1_score: 0.7339 - lr: 1.0000e-05
# Epoch 6/25
# 3681/3681 [==============================] - 673s 183ms/step - loss: 0.3878 - binary_accuracy: 0.8363 - precision: 0.8255 - recall: 0.7573 - cohen_kappa: 0.6563 - f1_score: 0.7899 - val_loss: 0.4333 - val_binary_accuracy: 0.8168 - val_precision: 0.7953 - val_recall: 0.7223 - val_cohen_kappa: 0.6105 - val_f1_score: 0.7571 - lr: 1.0000e-05
# Epoch 7/25
# 3681/3681 [==============================] - 624s 170ms/step - loss: 0.3613 - binary_accuracy: 0.8493 - precision: 0.8424 - recall: 0.7739 - cohen_kappa: 0.6836 - f1_score: 0.8067 - val_loss: 0.4579 - val_binary_accuracy: 0.7964 - val_precision: 0.7174 - val_recall: 0.8000 - val_cohen_kappa: 0.5824 - val_f1_score: 0.7565 - lr: 1.0000e-05
# Epoch 8/25
# 3681/3681 [==============================] - 622s 169ms/step - loss: 0.3450 - binary_accuracy: 0.8561 - precision: 0.8469 - recall: 0.7883 - cohen_kappa: 0.6984 - f1_score: 0.8166 - val_loss: 0.4404 - val_binary_accuracy: 0.8155 - val_precision: 0.7773 - val_recall: 0.7474 - val_cohen_kappa: 0.6116 - val_f1_score: 0.7621 - lr: 1.0000e-05
# Epoch 9/25
# 3681/3681 [==============================] - 620s 168ms/step - loss: 0.3209 - binary_accuracy: 0.8677 - precision: 0.8612 - recall: 0.8039 - cohen_kappa: 0.7228 - f1_score: 0.8316 - val_loss: 0.4402 - val_binary_accuracy: 0.8168 - val_precision: 0.7761 - val_recall: 0.7540 - val_cohen_kappa: 0.6148 - val_f1_score: 0.7649 - lr: 1.0000e-05
# Epoch 10/25
# 3681/3681 [==============================] - 607s 165ms/step - loss: 0.3016 - binary_accuracy: 0.8769 - precision: 0.8698 - recall: 0.8195 - cohen_kappa: 0.7424 - f1_score: 0.8439 - val_loss: 0.4475 - val_binary_accuracy: 0.8140 - val_precision: 0.7654 - val_recall: 0.7636 - val_cohen_kappa: 0.6109 - val_f1_score: 0.7645 - lr: 1.0000e-05
# Epoch 11/25
# 3681/3681 [==============================] - 613s 167ms/step - loss: 0.2828 - binary_accuracy: 0.8846 - precision: 0.8763 - recall: 0.8337 - cohen_kappa: 0.7590 - f1_score: 0.8545 - val_loss: 0.4534 - val_binary_accuracy: 0.8229 - val_precision: 0.7963 - val_recall: 0.7416 - val_cohen_kappa: 0.6250 - val_f1_score: 0.7680 - lr: 1.0000e-05
# Epoch 12/25
# 3681/3681 [==============================] - 624s 169ms/step - loss: 0.2574 - binary_accuracy: 0.8962 - precision: 0.8857 - recall: 0.8548 - cohen_kappa: 0.7836 - f1_score: 0.8700 - val_loss: 0.4823 - val_binary_accuracy: 0.8119 - val_precision: 0.7494 - val_recall: 0.7873 - val_cohen_kappa: 0.6099 - val_f1_score: 0.7679 - lr: 1.0000e-05
# Epoch 13/25
# 3681/3681 [==============================] - 629s 171ms/step - loss: 0.2366 - binary_accuracy: 0.9066 - precision: 0.8953 - recall: 0.8720 - cohen_kappa: 0.8055 - f1_score: 0.8835 - val_loss: 0.4924 - val_binary_accuracy: 0.8184 - val_precision: 0.7844 - val_recall: 0.7454 - val_cohen_kappa: 0.6168 - val_f1_score: 0.7644 - lr: 1.0000e-05
# Epoch 14/25
# 3681/3681 [==============================] - 1378s 374ms/step - loss: 0.2176 - binary_accuracy: 0.9158 - precision: 0.9056 - recall: 0.8851 - cohen_kappa: 0.8249 - f1_score: 0.8952 - val_loss: 0.5069 - val_binary_accuracy: 0.8136 - val_precision: 0.7752 - val_recall: 0.7443 - val_cohen_kappa: 0.6075 - val_f1_score: 0.7595 - lr: 1.0000e-05
# Epoch 15/25
# 3681/3681 [==============================] - ETA: 0s - loss: 0.1984 - binary_accuracy: 0.9232 - precision: 0.9129 - recall: 0.8966 - cohen_kappa: 0.8404 - f1_score: 0.9047
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 3681/3681 [==============================] - 759s 206ms/step - loss: 0.1984 - binary_accuracy: 0.9232 - precision: 0.9129 - recall: 0.8966 - cohen_kappa: 0.8404 - f1_score: 0.9047 - val_loss: 0.5425 - val_binary_accuracy: 0.8097 - val_precision: 0.7399 - val_recall: 0.7997 - val_cohen_kappa: 0.6074 - val_f1_score: 0.7686 - lr: 1.0000e-05
# Epoch 16/25
# 3681/3681 [==============================] - ETA: 0s - loss: 0.1537 - binary_accuracy: 0.9437 - precision: 0.9351 - recall: 0.9256 - cohen_kappa: 0.8830 - f1_score: 0.9303Restoring model weights from the end of the best epoch: 11.
# 3681/3681 [==============================] - 625s 170ms/step - loss: 0.1537 - binary_accuracy: 0.9437 - precision: 0.9351 - recall: 0.9256 - cohen_kappa: 0.8830 - f1_score: 0.9303 - val_loss: 0.5495 - val_binary_accuracy: 0.8215 - val_precision: 0.7846 - val_recall: 0.7560 - val_cohen_kappa: 0.6243 - val_f1_score: 0.7700 - lr: 2.0000e-06
# Epoch 16: early stopping

# %%
plot_metrics(finetune_history)

# %%
plot_accuracy(finetune_history)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# get the loss value & metrics values for the model in validation mode
evaluation_metrics = trained_model.evaluate(valid_batches, verbose=1)
# Out:
# 921/921 [==============================] - 63s 68ms/step - loss: 0.4534 - binary_accuracy: 0.8229 - precision: 0.7963 - recall: 0.7416 - cohen_kappa: 0.6250 - f1_score: 0.7680

# %%
loss = evaluation_metrics.pop(0)

print(f"val loss    : {loss}")
for metric, score in zip(METRICS, evaluation_metrics):

    print(f"{metric.name + ' ' * (12 - len(metric.name))}: {score}")
# Out:
# val loss    : 0.4534108638763428
# binary_accuracy: 0.8228742480278015
# precision   : 0.7963099479675293
# recall      : 0.7415807843208313
# cohen_kappa : 0.6250309348106384
# f1_score    : 0.7679715156555176

# %%
if os.path.isfile(finetune_path) is False:
    trained_model.save(finetune_path)
